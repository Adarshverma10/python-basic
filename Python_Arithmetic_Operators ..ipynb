# %% [markdown]
# # Python Arithmetic Operators – Final Solved Assignment
#
# > Note: Solutions use only print, f-strings, variables, input, and operators.

# %% [markdown]
# ## Q1 Addition

# %%
print(8 + 12)

# %% [markdown]
# ## Q2 Subtraction

# %%
print(20 - 7)

# %% [markdown]
# ## Q3 Multiplication

# %%
print(6 * 9)

# %% [markdown]
# ## Q4 Division

# %%
print(45 / 9)

# %% [markdown]
# ## Q5 Floor Division

# %%
print(45 // 9)
print(50 // 6)

# %% [markdown]
# ## Q6 Modulus

# %%
print(29 % 5)

# %% [markdown]
# ## Q7 Power

# %%
num = 3
power = 4
print(num ** power)

# %% [markdown]
# ## Q8 Unary plus and minus

# %%
x = 6
print(+x)
print(-x)

# %% [markdown]
# ## Q9 Operator precedence

# %%
print(5 + 3 * 2)
print((5 + 3) * 2)

# %% [markdown]
# ## Q10 Using variables

# %%
a = 15
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)

# %% [markdown]
# ## Q11 Compound assignment

# %%
n = 10
n += 5
print(n)
n *= 2
print(n)
n -= 4
print(n)

# %% [markdown]
# ## Q12 Swapping values

# %%
x = 3
y = 7
x, y = y, x
print(x, y)

# %% [markdown]
# ## Q13 Sum of two numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(f"Sum: {a + b}")

# %% [markdown]
# ## Q14 Average of three numbers

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
avg = (a + b + c) / 3
print(f"Average: {avg}")

# %% [markdown]
# ## Q15 Circle calculations

# %%
r = float(input("Enter radius: "))
pi = 3.14159
print(f"Circumference: {2 * pi * r}")
print(f"Area: {pi * r ** 2}")

# %% [markdown]
# ## Q16 Convert seconds to H:M:S

# %%
total = int(input("Enter total seconds: "))
hours = total // 3600
minutes = (total % 3600) // 60
seconds = total % 60
print(f"{hours}:{minutes}:{seconds}")

# %% [markdown]
# ## Q17 Simple Interest

# %%
p = float(input("Enter principal: "))
r = float(input("Enter rate: "))
t = float(input("Enter time: "))
si = (p * r * t) / 100
print(f"Interest: {si}")
